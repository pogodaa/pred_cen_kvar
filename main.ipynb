# %%
import cianparser
import pandas as pd
from time import sleep
import random
# import json

# def load_json_data(path):
#       with open(path) as json_file:
#             data = json.load(json_file)
#       return data

# json_file_path = 'proxy.json'
# proxy = load_json_data(json_file_path)

def get():
      rooms = range(1, 6)
      locations = [
            'Москва',
            'Новая Москва',
            'Московская область'
      ]

      main_data = []

      for main_count in range(1, 11):        
            for _location in locations:
                  for _room in rooms:
                        for num_strani in range(1,91):
                              sleep_time_value = random.randint(7, 11)
                              sleep(sleep_time_value)

                              _parcer = cianparser.CianParser(location=_location)
                              data = _parcer.get_flats(deal_type=('sale'), rooms=(_room), with_saving_csv=False, additional_settings={'start_page':num_strani, 'end_page':num_strani}, with_extra_data=True)
                              
                              if data:
                                    main_data.extend(data)
                              
                                    sleep(sleep_time_value)


            if main_data:
                  df = pd.DataFrame(main_data)
                  df.to_csv('baza.csv', index=False, encoding='utf-8')
                              

get()
# Out:
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 236 041 818 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
# Collecting information from pages with list of offers
#  1 | 2 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 3. Progress ratio: 11 %. Average price: 49 347 415 rub
#  1 | 2 page with list: [=>                                                      ] 4% | Count of all parsed: 3. Progress ratio: 11 %. Average price: 49 347 415 rub
#  1 | 2 page with list: [=>                                                      ] 4% | Count of all parsed: 4. Progress ratio: 15 %. Average price: 55 597 415 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/299019831/
# The collection of information from the pages with ending parse on 2 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 4.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=3&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
# Collecting information from pages with list of offers
#  1 | 3 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 4 %. Average price: 17 903 652 rub
#  1 | 3 page with list: [=>                                                      ] 4% | Count of all parsed: 2. Progress ratio: 8 %. Average price: 21 593 652 rub
#  3 page: 28 offers
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/305005720/
# The collection of information from the pages with ending parse on 3 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 2.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=4&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
# Collecting information from pages with list of offers
#  1 | 4 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 8 %. Average price: 31 803 652 rub
#  1 | 4 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 8 %. Average price: 31 803 652 rub
#  1 | 4 page with list: [=>=>=>                                                  ] 11% | Count of all parsed: 3. Progress ratio: 11 %. Average price: 34 920 318 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/292442349/
# The collection of information from the pages with ending parse on 4 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 3.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=5&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
# Collecting information from pages with list of offers
#  1 | 5 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 4 %. Average price: 12 860 000 rub
#  1 | 5 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 4 %. Average price: 12 860 000 rub
#  1 | 5 page with list: [=>=>                                                    ] 8% | Count of all parsed: 2. Progress ratio: 8 %. Average price: 17 810 000 rub
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/sale/flat/309018369/
# The collection of information from the pages with ending parse on 5 page...
#
#
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 2.
#
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=6&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
# Collecting information from pages with list of offers
#  1 | 6 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 4 %. Average price: 22 378 095 rub
#  6 page: 28 offers
#  1 | 6 page with list: [=>                                                      ] 4% | Count of all parsed: 1. Progress ratio: 4 %. Average price: 22 378 095 rub
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 46
#      42                   df = pd.DataFrame(main_data)
#      43                   df.to_csv('baza.csv', index=False, encoding='utf-8')
# ---> 46 get()
#
# Cell In[2], line 33, in get()
#      30 sleep(sleep_time_value)
#      32 _parcer = cianparser.CianParser(location=_location)
# ---> 33 data = _parcer.get_flats(deal_type=('sale'), rooms=(_room), with_saving_csv=False, additional_settings={'start_page':num_strani, 'end_page':num_strani}, with_extra_data=True)
#      35 if data:
#      36       main_data.extend(data)
#
# File c:\Users\Andre\AppData\Local\Programs\Python\Python312\Lib\site-packages\cianparser\cianparser.py:119, in CianParser.get_flats(self, deal_type, rooms, with_saving_csv, with_extra_data, additional_settings)
#     108 deal_type, rent_period_type = __define_deal_type__(deal_type)
#     109 self.__parser__ = FlatListPageParser(
#     110     session=self.__session__,
#     111     accommodation_type="flat",
#    (...)
#     117     additional_settings=additional_settings,
#     118 )
# --> 119 self.__run__(
#     120     __build_url_list__(location_id=self.__location_id__, deal_type=deal_type, accommodation_type="flat",
#     121                        rooms=rooms, rent_period_type=rent_period_type,
#     122                        additional_settings=additional_settings))
#     123 return self.__parser__.result
#
# File c:\Users\Andre\AppData\Local\Programs\Python\Python312\Lib\site-packages\cianparser\cianparser.py:75, in CianParser.__run__(self, url_list_format)
#      73 while attempt_number_exception < 3 and not page_parsed:
#      74     try:
# ---> 75         (page_parsed, attempt_number, end_all_parsing) = self.__parser__.parse_list_offers_page(
#      76             html=self.__load_list_page__(url_list_format=url_list_format, page_number=page_number, attempt_number_exception=attempt_number_exception),
#      77             page_number=page_number,
#      78             count_of_pages=self.__parser__.end_page + 1 - self.__parser__.start_page,
#      79             attempt_number=attempt_number_exception)
#      81     except Exception as e:
#      82         attempt_number_exception += 1
#
# File c:\Users\Andre\AppData\Local\Programs\Python\Python312\Lib\site-packages\cianparser\flat\list.py:38, in FlatListPageParser.parse_list_offers_page(self, html, page_number, count_of_pages, attempt_number)
#      35     print(f"Collecting information from pages with list of offers", end="\n")
#      37 for ind, offer in enumerate(offers):
# ---> 38     self.parse_offer(offer=offer)
#      39     self.print_parse_progress(page_number=page_number, count_of_pages=count_of_pages, offers=offers, ind=ind)
#      41 time.sleep(2)
#
# File c:\Users\Andre\AppData\Local\Programs\Python\Python312\Lib\site-packages\cianparser\flat\list.py:64, in FlatListPageParser.parse_offer(self, offer)
#      62     flat_parser = FlatPageParser(session=self.session, url=common_data["url"])
#      63     page_data = flat_parser.parse_page()
# ---> 64     time.sleep(4)
#      66 self.count_parsed_offers += 1
#      67 self.define_average_price(price_data=price_data)
#
# KeyboardInterrupt:
